# %%
import numpy as np
import cv2
import PIL.Image as Image
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Image.open(r"C:\Users\varun\Desktop\Image Classification\model\dataset\Anushka Shetty\47.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=746x746>

# %%
face_cascade = cv2.CascadeClassifier("./opencv/haarcascades/haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("./opencv/haarcascades/haarcascade_eye.xml")

# %%
def get_cropped_image_if_2_eyes(image_path):
    list=[]
    try:
        img = cv2.imread(image_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray,1.3,5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h,x:x+w]
            roi_color = img[y:y+h,x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes)>=2:
                list.append(roi_color)
        return list
    except:
        pass

# %%
original_image = cv2.imread(r"C:\Users\varun\Desktop\Image Classification\model\dataset\Anushka Shetty\47.jpg")
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes(r"C:\Users\varun\Desktop\Image Classification\model\dataset\Anushka Shetty\47.jpg")
len(cropped_image)
# Out:
# 2
